# %% [markdown]
# <a href="https://colab.research.google.com/github/booysej/ds-personal/blob/main/WASA_Wind_Turbine_Placement_Multiple_Objective_Genetic_Algorithm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Data: http://wasadata.csir.co.za/wasa1/WASAData?pscreen=timeseries
# ![image.png](data:image/png;base64,...)
