# %%
# !git clone https://github.com/ploomber/soopervisor
# Out:
# Cloning into 'soopervisor'...
# remote: Enumerating objects: 4937, done.
# remote: Counting objects: 100% (1929/1929), done.
# remote: Compressing objects: 100% (540/540), done.
# remote: Total 4937 (delta 1445), reused 1602 (delta 1301), pack-reused 3008
# Receiving objects: 100% (4937/4937), 1.03 MiB | 1.55 MiB/s, done.
# Resolving deltas: 100% (3025/3025), done.

# %%
!(cd soopervisor/tutorials/workflow; docker build --tag ploomber-workflow .)
# Out:
# [+] Building 0.0s (0/0)                                    docker:desktop-linux
# [+] Building 0.0s (0/2)                                    docker:desktop-linux
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 30B                                        0.0s
# [+] Building 0.2s (2/3)                                    docker:desktop-linux
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 2.19kB                                     0.0s
#  => [internal] load metadata for docker.io/continuumio/miniconda3:latest   0.1s
# ...

# %%
# !rm -rf ./ploomber-workflow
# !mkdir -p ./ploomber-workflow

# %%
# Run on terminal
# start (takes ~1 minute to be ready)

# %% [markdown]
# docker run -i -t \
#     --privileged=true -v /var/run/docker.sock:/var/run/docker.sock \
#     --volume /Users/jacques/mnt/ds-personal/Ploomber/ploomber-workflow:/mnt/shared-folder \
#     --env SHARED_DIR \
#     --env PLOOMBER_STATS_ENABLED=false \
#     --network host \
#     ploomber-workflow
