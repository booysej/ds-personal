# %%
upstream = list('clean')
product = NULL

# %%
# Parameters
upstream = list("clean" = list("nb" = "/Users/jacques/mnt/ds-personal/Ploomber/examples/example1-r/output/clean.ipynb", "data" = "/Users/jacques/mnt/ds-personal/Ploomber/examples/example1-r/output/clean.csv"))
product = list("nb" = "/Users/jacques/mnt/ds-personal/Ploomber/examples/example1-r/output/plot.ipynb")

# %%
df = read.csv(upstream$clean$data)
head(df)
# Out:
#   X.1 X sepal_length sepal_width petal_length petal_width class
# 1 1   1 5.1          3.5         1.4          0.2         setosa
# 2 2   2 4.9          3.0         1.4          0.2         setosa
# 3 3   3 4.7          3.2         1.3          0.2         setosa
# 4 4   4 4.6          3.1         1.5          0.2         setosa
# 5 5   5 5.0          3.6         1.4          0.2         setosa
# 6 6   6 5.4          3.9         1.7          0.4         setosa

# %%
par(bg = "#FFFFFF")
hist(df$sepal_length)
# Out:
# Plot with title “Histogram of df$sepal_length”
